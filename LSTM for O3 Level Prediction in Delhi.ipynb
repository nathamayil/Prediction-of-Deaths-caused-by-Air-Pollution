# %%
import pandas as pd
import numpy as np
from pathlib import Path
from fastprogress import progress_bar
import matplotlib.pyplot as plt
import seaborn as sns
from hepml.core import plot_regression_tree, plot_predictions

sns.set(color_codes=True)
sns.set_palette(sns.color_palette("muted"))

from sklearn.ensemble import GradientBoostingRegressor, GradientBoostingClassifier
from sklearn.tree import DecisionTreeRegressor
from sklearn.model_selection import train_test_split, RandomizedSearchCV
from sklearn.metrics import mean_squared_error, roc_auc_score, accuracy_score

# %%
#Reading Data and isolating just the required pollutant
col_list = ["Date","O3"]
data = pd.read_csv("O3Dtr.csv", usecols=col_list,index_col ="Date")
data.head()
# Out:
#              O3
# Date
# 1/1/2015  41.68
# 1/2/2015  29.97
# 1/3/2015  19.71
# 1/4/2015  25.36
# 1/5/2015  23.20

# %%
#Dropping null values
data.dropna(subset = ["O3"], inplace=True)

# %%
plt.rcParams['figure.figsize'] = [18, 18]
data.plot(color='green')
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
#Autocorrelation Plot
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf
plot_acf(data);

# %%
#partial autocorrelation
plot_pacf(data);

# %%
from keras.models import Sequential
from keras.layers import LSTM
from keras.layers import Dense
model = Sequential()
model.add(LSTM(50, activation='relu'))
model.add(Dense(1))
model.compile(optimizer='adam', loss='mse')

# %%
#scaling data
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler(feature_range = (0, 1))

df= scaler.fit_transform(data)

# %%
#creating feature and label sets
features_set = []
labels = []
for i in range(60, 1840):
    features_set.append(df[i-60:i, 0])
    labels.append(df[i,0])

# %%
#converting both the feature_set and the labels list to the numpy array before we can use it for training
features_set, labels = np.array(features_set), np.array(labels)

# %%
#fitting it for the model dimension
features_set = np.reshape(features_set, (features_set.shape[0], features_set.shape[1], 1))

# %%
#Training the LSTM 
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM
from keras.layers import Dropout

# %%
model = Sequential()

# %%
#adding LSTM layer to the model
model.add(LSTM(units=50, return_sequences=True, input_shape=(features_set.shape[1], 1)))

# %%
#Adding dropout layer to avoid over-fitting (a situation where a machine learning model performs better on the training data compared to the test data.)
model.add(Dropout(0.2))

# %%
#adding 3 more LSTM and dropout models
model.add(LSTM(units=50, return_sequences=True))
model.add(Dropout(0.2))
model.add(LSTM(units=50, return_sequences=True))
model.add(Dropout(0.2))
model.add(LSTM(units=50))
model.add(Dropout(0.2))

# %%
#adding a dense layer at the end of the model to make it more robust(set to 1 since we want to predict a single value in the output)
model.add(Dense(units = 1))

# %%
#compiling our LSTM before we can train it on the training data
#the mean squared error is used as loss function and to reduce the loss or to optimize the algorithm,the adam optimizer is used.
model.compile(optimizer = 'adam', loss = 'mean_squared_error')

# %%
#calling the fit method on the model and pass it our training features and labels
model.fit(features_set, labels, epochs = 100, batch_size = 32)
# Out:
# Epoch 1/100
# 56/56 [==============================] - 7s 58ms/step - loss: 0.0092
# Epoch 2/100
# 56/56 [==============================] - 3s 57ms/step - loss: 0.0061
# Epoch 3/100
# 56/56 [==============================] - 3s 57ms/step - loss: 0.0066
# Epoch 4/100
# 56/56 [==============================] - 3s 55ms/step - loss: 0.0059
# Epoch 5/100
# 56/56 [==============================] - 3s 55ms/step - loss: 0.0056
# Epoch 6/100
# 56/56 [==============================] - 3s 55ms/step - loss: 0.0059
# Epoch 7/100
# 56/56 [==============================] - 3s 56ms/step - loss: 0.0053
# Epoch 8/100
# 56/56 [==============================] - 3s 55ms/step - loss: 0.0051
# Epoch 9/100
# 56/56 [==============================] - 3s 55ms/step - loss: 0.0050
# Epoch 10/100
# 56/56 [==============================] - 3s 55ms/step - loss: 0.0047
# Epoch 11/100
# 56/56 [==============================] - 3s 55ms/step - loss: 0.0045
# Epoch 12/100
# 56/56 [==============================] - 3s 55ms/step - loss: 0.0047
# Epoch 13/100
# 56/56 [==============================] - 3s 56ms/step - loss: 0.0041
# Epoch 14/100
# 56/56 [==============================] - 3s 60ms/step - loss: 0.0040
# Epoch 15/100
# 56/56 [==============================] - 3s 59ms/step - loss: 0.0039
# Epoch 16/100
# 56/56 [==============================] - 3s 56ms/step - loss: 0.0041
# Epoch 17/100
# 56/56 [==============================] - 3s 55ms/step - loss: 0.0040
# Epoch 18/100
# 56/56 [==============================] - 3s 55ms/step - loss: 0.0039
# Epoch 19/100
# 56/56 [==============================] - 3s 56ms/step - loss: 0.0039
# Epoch 20/100
# 56/56 [==============================] - 3s 55ms/step - loss: 0.0039
# Epoch 21/100
# 56/56 [==============================] - 3s 55ms/step - loss: 0.0040
# Epoch 22/100
# 56/56 [==============================] - 3s 55ms/step - loss: 0.0038
# Epoch 23/100
# 56/56 [==============================] - 3s 56ms/step - loss: 0.0036
# Epoch 24/100
# 56/56 [==============================] - 4s 68ms/step - loss: 0.0038
# Epoch 25/100
# 56/56 [==============================] - 4s 67ms/step - loss: 0.0038
# Epoch 26/100
# 56/56 [==============================] - 4s 64ms/step - loss: 0.0037
# Epoch 27/100
# 56/56 [==============================] - 4s 63ms/step - loss: 0.0038
# Epoch 28/100
# 56/56 [==============================] - 4s 63ms/step - loss: 0.0035
# Epoch 29/100
# 56/56 [==============================] - 4s 63ms/step - loss: 0.0034
# Epoch 30/100
# 56/56 [==============================] - 3s 62ms/step - loss: 0.0035
# Epoch 31/100
# 56/56 [==============================] - 3s 62ms/step - loss: 0.0036
# Epoch 32/100
# 56/56 [==============================] - 4s 73ms/step - loss: 0.0033
# Epoch 33/100
# 56/56 [==============================] - 5s 95ms/step - loss: 0.0034
# Epoch 34/100
# 56/56 [==============================] - 4s 77ms/step - loss: 0.0035
# Epoch 35/100
# 56/56 [==============================] - 4s 64ms/step - loss: 0.0033
# Epoch 36/100
# 56/56 [==============================] - 3s 62ms/step - loss: 0.0034
# Epoch 37/100
# 56/56 [==============================] - 4s 64ms/step - loss: 0.0033
# Epoch 38/100
# 56/56 [==============================] - 3s 62ms/step - loss: 0.0033
# Epoch 39/100
# 56/56 [==============================] - 3s 61ms/step - loss: 0.0033
# Epoch 40/100
# 56/56 [==============================] - 4s 63ms/step - loss: 0.0034
# Epoch 41/100
# 56/56 [==============================] - 3s 62ms/step - loss: 0.0034
# Epoch 42/100
# 56/56 [==============================] - 3s 62ms/step - loss: 0.0033
# Epoch 43/100
# 56/56 [==============================] - 3s 62ms/step - loss: 0.0031
# Epoch 44/100
# 56/56 [==============================] - 3s 62ms/step - loss: 0.0033
# Epoch 45/100
# 56/56 [==============================] - 4s 63ms/step - loss: 0.0033
# Epoch 46/100
# 56/56 [==============================] - 3s 62ms/step - loss: 0.0034
# Epoch 47/100
# 56/56 [==============================] - 3s 62ms/step - loss: 0.0032
# Epoch 48/100
# 56/56 [==============================] - 4s 65ms/step - loss: 0.0032
# Epoch 49/100
# 56/56 [==============================] - 4s 72ms/step - loss: 0.0034
# Epoch 50/100
# 56/56 [==============================] - 3s 62ms/step - loss: 0.0031
# Epoch 51/100
# 56/56 [==============================] - 3s 62ms/step - loss: 0.0032
# Epoch 52/100
# 56/56 [==============================] - 3s 62ms/step - loss: 0.0032
# Epoch 53/100
# 56/56 [==============================] - 3s 62ms/step - loss: 0.0031
# Epoch 54/100
# 56/56 [==============================] - 3s 62ms/step - loss: 0.0032
# Epoch 55/100
# 56/56 [==============================] - 3s 62ms/step - loss: 0.0031
# Epoch 56/100
# 56/56 [==============================] - 3s 62ms/step - loss: 0.0032
# Epoch 57/100
# 56/56 [==============================] - 3s 62ms/step - loss: 0.0032
# Epoch 58/100
# 56/56 [==============================] - 3s 61ms/step - loss: 0.0033
# Epoch 59/100
# 56/56 [==============================] - 3s 62ms/step - loss: 0.0033
# Epoch 60/100
# 56/56 [==============================] - 3s 62ms/step - loss: 0.0031
# Epoch 61/100
# 56/56 [==============================] - 3s 61ms/step - loss: 0.0032
# Epoch 62/100
# 56/56 [==============================] - 4s 66ms/step - loss: 0.0032
# Epoch 63/100
# 56/56 [==============================] - 3s 61ms/step - loss: 0.0032
# Epoch 64/100
# 56/56 [==============================] - 3s 62ms/step - loss: 0.0031
# Epoch 65/100
# 56/56 [==============================] - 3s 62ms/step - loss: 0.0031
# Epoch 66/100
# 56/56 [==============================] - 4s 73ms/step - loss: 0.0031
# Epoch 67/100
# 56/56 [==============================] - 4s 63ms/step - loss: 0.0031
# Epoch 68/100
# 56/56 [==============================] - 3s 62ms/step - loss: 0.0031
# Epoch 69/100
# 56/56 [==============================] - 3s 62ms/step - loss: 0.0031
# Epoch 70/100
# 56/56 [==============================] - 3s 62ms/step - loss: 0.0031
# Epoch 71/100
# 56/56 [==============================] - 4s 67ms/step - loss: 0.0032
# Epoch 72/100
# 56/56 [==============================] - 4s 67ms/step - loss: 0.0031
# Epoch 73/100
# 56/56 [==============================] - 4s 63ms/step - loss: 0.0031
# Epoch 74/100
# 56/56 [==============================] - 4s 63ms/step - loss: 0.0031
# Epoch 75/100
# 56/56 [==============================] - 3s 61ms/step - loss: 0.0031
# Epoch 76/100
# 56/56 [==============================] - 3s 62ms/step - loss: 0.0031
# Epoch 77/100
# 56/56 [==============================] - 3s 62ms/step - loss: 0.0031: 0s - loss:
# Epoch 78/100
# 56/56 [==============================] - 3s 62ms/step - loss: 0.0031
# Epoch 79/100
# 56/56 [==============================] - 3s 62ms/step - loss: 0.0032
# Epoch 80/100
# 56/56 [==============================] - 3s 62ms/step - loss: 0.0031
# Epoch 81/100
# 56/56 [==============================] - 3s 62ms/step - loss: 0.0031
# Epoch 82/100
# 56/56 [==============================] - 4s 65ms/step - loss: 0.0031
# Epoch 83/100
# 56/56 [==============================] - 4s 69ms/step - loss: 0.0030
# Epoch 84/100
# 56/56 [==============================] - 3s 62ms/step - loss: 0.0032
# Epoch 85/100
# 56/56 [==============================] - 3s 62ms/step - loss: 0.0031
# Epoch 86/100
# 56/56 [==============================] - 3s 62ms/step - loss: 0.0030
# Epoch 87/100
# 56/56 [==============================] - 3s 62ms/step - loss: 0.0032
# Epoch 88/100
# 56/56 [==============================] - 3s 61ms/step - loss: 0.0030
# Epoch 89/100
# 56/56 [==============================] - 3s 62ms/step - loss: 0.0030
# Epoch 90/100
# 56/56 [==============================] - 3s 62ms/step - loss: 0.0030
# Epoch 91/100
# 56/56 [==============================] - 3s 62ms/step - loss: 0.0030
# Epoch 92/100
# 56/56 [==============================] - 3s 62ms/step - loss: 0.0030
# Epoch 93/100
# 56/56 [==============================] - 3s 62ms/step - loss: 0.0030
# Epoch 94/100
# 56/56 [==============================] - 3s 62ms/step - loss: 0.0030
# Epoch 95/100
# 56/56 [==============================] - 3s 62ms/step - loss: 0.0030
# Epoch 96/100
# 56/56 [==============================] - 3s 62ms/step - loss: 0.0030
# Epoch 97/100
# 56/56 [==============================] - 3s 62ms/step - loss: 0.0030
# Epoch 98/100
# 56/56 [==============================] - 3s 62ms/step - loss: 0.0030
# Epoch 99/100
# 56/56 [==============================] - 3s 62ms/step - loss: 0.0030
# Epoch 100/100
# 56/56 [==============================] - 4s 72ms/step - loss: 0.0031

# %%
#importing test data
col_list = ["Date","O3"]
data1 = pd.read_csv("O3Dt.csv", usecols=col_list,index_col ="Date")
data1.dropna(subset = ["O3"], inplace=True)
data1.head()
# Out:
#               O3
# Date
# 4/8/2020   45.80
# 4/9/2020   48.34
# 4/10/2020  40.36
# 4/11/2020  49.51
# 4/12/2020  50.15

# %%
#concatenating our training data and test data before preprocessing
datat = pd.concat((data['O3'], data1['O3']), axis=0)

# %%
#fetching 60 days values for test input
test_inputs = datat[len(datat) - len(data1) - 60:].values

# %%
#scaling our test data
test_inputs = test_inputs.reshape(-1,1)
test_inputs = scaler.transform(test_inputs)

# %%
#preparing our final test input set containing pollutant level for 60 days
test_features = []
for i in range(60, 80):
    test_features.append(test_inputs[i-60:i, 0])

# %%
#converting our data into 3-d format which can be used as input to the LSTM
test_features = np.array(test_features)
test_features = np.reshape(test_features, (test_features.shape[0], test_features.shape[1], 1))

# %%
#Making the prediction
predictions = model.predict(test_features)

# %%
#Using scaler inverse transform to reverse the scaled prediction back to their actual values
predictions = scaler.inverse_transform(predictions)

# %%
plt.figure(figsize=(80,20))
plt.plot(data1, color='blue', label='Actual O3 Levels')
plt.plot(predictions , color='red', label='Predicted O3 Levels')
plt.title('O3 Level Predictions')
plt.xlabel('Date')
plt.ylabel('O3 Levels')
plt.legend()
plt.show()

# %%
accuracy_score(data1, predictions, normalize=False)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-30-0dffc5491cde> in <module>
# ----> 1 accuracy_score(data1, predictions, normalize=False)
#
# ~\anaconda3\lib\site-packages\sklearn\utils\validation.py in inner_f(*args, **kwargs)
#      61             extra_args = len(args) - len(all_args)
#      62             if extra_args <= 0:
# ---> 63                 return f(*args, **kwargs)
#      64
#      65             # extra_args > 0
#
# ~\anaconda3\lib\site-packages\sklearn\metrics\_classification.py in accuracy_score(y_true, y_pred, normalize, sample_weight)
#     200
#     201     # Compute accuracy for each possible representation
# --> 202     y_type, y_true, y_pred = _check_targets(y_true, y_pred)
#     203     check_consistent_length(y_true, y_pred, sample_weight)
#     204     if y_type.startswith('multilabel'):
#
# ~\anaconda3\lib\site-packages\sklearn\metrics\_classification.py in _check_targets(y_true, y_pred)
#      81     y_pred : array or indicator matrix
#      82     """
# ---> 83     check_consistent_length(y_true, y_pred)
#      84     type_true = type_of_target(y_true)
#      85     type_pred = type_of_target(y_pred)
#
# ~\anaconda3\lib\site-packages\sklearn\utils\validation.py in check_consistent_length(*arrays)
#     260     uniques = np.unique(lengths)
#     261     if len(uniques) > 1:
# --> 262         raise ValueError("Found input variables with inconsistent numbers of"
#     263                          " samples: %r" % [int(l) for l in lengths])
#     264
#
# ValueError: Found input variables with inconsistent numbers of samples: [85, 20]
